# %% [markdown]
# <a href="https://colab.research.google.com/github/AprilMilagros/curriculum/blob/main/Apuntes_M_A_C_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Apuntes
#
# ####Nombre de los alumnos:
#
# Aguilar Jiménez Cristian Jesús(22011476)
#
# Álvarez Hernández Edwin(220111015)
#
# Bautista Flores Alondra(220118706)
#
# Cruz Godinez Samuel(22011514)
#
# Falcon-Caracas April Milagros(22011797)
#
# Lopez Martinez Marco Antonio(22011918)
#
# ####Asignatura: Matematicas Aplicadas a Comunicaciones
#
# ####Fecha de entrega: 22/11/2023
#
# ##COMPETENCIA ESPECÍFICA
#
# Emplea diferentes herramientas matemáticas en la solución de problemas de
# modelado de sistemas dinámicos lineales
#
# ##Temario:
# ### Ecuaciones diferenciales de primer orden:
#
# * 1.1. Clasificación de ecuaciones diferenciales.
#
# * 1.2. Teorema de existencia y unicidad.
#
# * 1.3. Métodos para resolver ecuaciones diferenciales de primer orden.
#
# * 1.4. Diferencias entre las ecuaciones diferenciales lineales y las no lineales.
#
# * 1.5. Aplicaciones.
#
# ### Transformada de Laplace:
#
# * 2.1. Definición y propiedades de la transformada de Laplace.
#
# * 2.2. Condiciones suficientes de existencia para la transformada de
# Laplace.
#
# * 2.3. Transformada directa.
#
# * 2.4. Transformada inversa.
#
# * 2.5. Transformada de derivadas (teorema).
#
# * 2.6. Transformada de integrales (teorema).
#
# * 2.7. Teorema de la consolación.
#
# * 2.8. Transformada de Laplace de una función periódica.
#
# * 2.9. Solución de ecuaciones diferenciales.
#
# ###Series de Fourier:
#
# * 3.1. Concepto, clasificación y caracterización de señales.
#
# * 3.2. Representación de señales usando serie trigonométrica de Fourier.
#
# * 3.3. Representación de señales usando serie compleja de Fourier.
#
# ##FUENTES DE INFORMACIÓN
#
# * Boyce, W.E., DiPrima, R.C. Ecuaciones diferenciales y problemas en la frontera.4ª.
# Edición. Ed. Limusa.
#
# * Zill, Dennis G. Ecuaciones diferenciales con aplicaciones de modelado. 7ª. Edición. Ed.
# Thomson Learning.
#
# * Proakis, John D. Digital Signal Processing. 4ª. Edición. Ed. Prentice Hall.
#
# * Hsu, Hwei P. Análisis de Fourier. 1ª. Edición. Ed. Alhambra Mexicana. México. 2000.
#
# * Kuo, Benjamin C. Sistemas de Control Digital.1ª. Edición. 1997. Ed. McGraw Hill. 
# Ogata, Katsuhiko. Sistemas de Control en Tiempo Discreto. 2ª.edición. Ed. Prentice Hall.
#
# * Referencia electrónica: http://books.google.com.mx/ Algunos de los ejemplares antes
# mencionados se pueden encontrar en este sitio para su respectiva consulta.

# %% [markdown]
# #**Introducción a las ecuaciones diferenciales**
#
# >Entre todas las disciplinas matemáticas. La teoría de las ecuaciones diferenciales es la más importante. Proporciona la explicación de todas esas manifestaciones elementales de la naturaleza que involucran el tiempo.
#
# >Definamos a una ecuación diferencial como una ecuación que contiene las derivadas de una o varias variables dependientes con respecto a una o varias variables independientes; A estas se les conoce como ecuaciones diferenciales.
#
# ### Características
#
# >Tipos de ecuaciones diferenciales.
#
# >Dependiendo del numero de variables independientes respecto de las que derivan, las ecuaciones diferenciales se dividen en dos tipos:
#
# ####Ecuaciones diferenciales ordinarias:
# >Son aquellas que contienen derivadas respecto a una sola variable independiente.
#
# ####Ecuaciones diferenciales parciales:
# >Aquellas que contienen derivadas respecto a dos o más variables independientes
#
# ### Orden de la derivada
# >Es el número de veces que se deriva a una función o primitiva
#
# ### Grado de la derivada
#
# >El grado de la derivada es el exponente o potencia de la derivada

# %% [markdown]
# $f(x) = y = x^3$
#
# $f(x) = y' = 3x^2$ &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $y' = \text{Primer orden}$
#
# $f(x) = y'' = 6x$ &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $y'' = \text{Segundo orden}$
#
# $f(x) = y''' = 6$ &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $y''' = \text{Tercer orden}$

# %% [markdown]
# ###$\frac{{dy}}{{dx}} \left|{\substack{\text{Variable independiente} = x \\ \text{Variable dependiente} = y}}\right.$

# %% [markdown]
# ####${{Ecuación Diferencial}} \left|{\substack{\text{Ordinaria} \frac{{d^2 y}}{{dx^2}} + 5x \frac{{dy}}{{dx}} + 7y = e^x \\  \text{Parcial}\frac{{d^2 y}}{{dw^2}} + 5 \frac{{dz}}{{dw}} + \frac{{dm}}{{dn}}  = e^n}}\right.$
#
#  <table class="demo">
# 	<caption> Ordinaria</caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;X</td>
# 		<td>&nbsp;2</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;Y</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	</tbody>
# </table>
#  Ecuacion diferencial Ordinaria de 2° orden con grado 1°.
#  <table class="demo">
# 	<caption>Parcial</caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;W,N</td>
# 		<td>&nbsp;2</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;Y,Z,M</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	</tbody>
# </table>
# Ecuacion diferencial Parcial de 2° orden con grado 1°, lineal.

# %% [markdown]
# ##Ejercicios
#
# ###1)$  \frac{d^2y}{dt^2}+5t+\frac{dy}{dt}+y=-3t^2 $
#
# <table class="demo">
# 	<caption></caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;T</td>
# 		<td>&nbsp;2</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;Y</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	</tbody>
# </table>
#
# ### Ecuacion diferencial Ordinaria de 2° orden con grado 1°.
#
# ### 2) $  \frac{d^4m}{ds^4}-3\frac{d^2m}{ds^2}+\frac{dm}{ds}=e^-25 $
#
# <table class="demo">
# 	<caption></caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;S</td>
# 		<td>&nbsp;4</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;M</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	</tbody>
# </table>
#
# ### Ecuación diferencial ordinaria de 4° orden con grado 1°.
#
# ## 3) $  \frac{d^3v}{du^3}-3\frac{d^2u}{r^2}-\frac{5dm}{dk}=0 $
#
# <table class="demo">
# 	<caption></caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;U,R,K</td>
# 		<td>&nbsp;3</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;I</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	</tbody>
# </table>
#
# ### Ecuación diferencial parcial de 3° orden con grado 1°.
#
# ## 4) $  5xy^5+\frac{3}{x^2}yy^2-4y=0 $
# <table class="demo">
# 	<caption></caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;X</td>
# 		<td>&nbsp;5</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;Y</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	</tbody>
# </table>
#
# ### Ecuación diferencial ordinaria de 5° orden con grado 1°.
#
# ## 5) $  3t\frac{d^2z}{dt^2}-3(\frac{dz}{dt})^4+5z=2t sen t $
#
# <table class="demo">
# 	<caption></caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;t</td>
# 		<td>&nbsp;2</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;z</td>
# 		<td>&nbsp;4</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	</tbody>
# </table>
#
# ### Ecuación diferencial ordinaria de 2° orden con grado 4°
#
# ## 6) $ \sqrt{(\frac{d^2y}{dm^3})} = 3\sqrt{(\frac{1-dy^2}{dm})} $
# <table class="demo">
# 	<caption></caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;m</td>
# 		<td>&nbsp;3</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;y</td>
# 		<td>&nbsp;3/2</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	</tbody>
# </table>
#
# ### Ecuación diferencial ordinaria de 3° orden con grado 1°.

# %% [markdown]
# ## **linealidad de una ecuación diferencial**
#
# >Una ecuación diferencial ordinaria de orden "n" es lineal, cuando se puede escribir de la siguente forma:
#
# $$a_{n}(x)y^{(n)}+a_{n-1}(x)y^{(n-1)}+a_{n-2}(x)y^{(n-2)}+.....+a_{1}(x)y^{(1)}+a_{0}(x)y^{(0)}= \left|{\substack{\text{0}  \\ \text{g(x)}}}\right.$$
#
# >En esta ecuación vemos dos propiedades características de una ecuación diferencial ordinaria lineal.
#
# >**i)** La variable dependiente “y” y todas sus derivadas tienen como potencia el número 1. No debe haber funciones de “y”  y sus derivadas que no sean lineales.
#
# >**i)** Todas las funciones $a_i (x)$ que aparecen como crecientes de "y" y sus derivadas deben depender exclusivamente de **x**.
#
# ###Ejemplo
#
# ###$4x(\frac{dy}{dx})+y=x$
#
# <table class="demo">
# 	<caption>tabla 1</caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden</td>
# 		<td>&nbsp;i)</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;x</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;SI</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;ii)</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;y</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;Si</td>
# 	</tr>
# 	</tbody>
# </table>
#
# ### Ecuación diferencial ordinaria de 3° orden con grado 1°,lineal

# %% [markdown]
# ##Ejercicios
#
# ###$ 1) y"-2y´+y=0 $
# <table class="demo">
# 	<caption>tabla 10</caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;i)</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;x</td>
# 		<td>&nbsp;2</td>
# 		<td>&nbsp;Si</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;ii)</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;y</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;Si</td>
# 	</tr>
# 	</tbody>
# </table>
#
# ### Ecuación diferencial ordinaria de 2° orden con grado 1°,lineal.
#
# ###$2) x^2\frac{d^3y}{dx^3}+x\frac{dy}{dx}-5y=e^x $
#
# <table class="demo">
# 	<caption>tabla 11</caption>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;i)</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;x</td>
# 		<td>&nbsp;3</td>
# 		<td>&nbsp;Si</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;ii)</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;y</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;Si</td>
# 	</tr>
# 	</tbody>
# </table>
#
#
# ### Ecuación diferencial ordinaria de 3° orden con grado 1°,lineal.
#
# ### 3) $ y^2 \frac{d^5y}{dx^5}+x\frac{dy}{dx}-5(y)=e^x $
# <table class="demo">
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;Ordinaria&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;V.I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;Orden&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# 		<td>&nbsp;i)</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;SI</td>
# 		<td>&nbsp;x</td>
# 		<td>&nbsp;3</td>
# 		<td>&nbsp;No</td>
# 	</tr>
# 	<tr>
# 		<td>Parcial</td>
# 		<td>&nbsp;V.D</td>
# 		<td>&nbsp;Grado</td>
# 		<td>&nbsp;ii)</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;NO</td>
# 		<td>&nbsp;y</td>
# 		<td>&nbsp;1</td>
# 		<td>&nbsp;NO</td>
# 	</tr>
# 	</tbody>
# </table>
#
# ### Ecuación diferencial ordinaria de 3° orden con grado 1°, No lineal.

# %% [markdown]
# ##Solución a una EC.Dif.Ordinaria
#
# >La solución de una EC.Dif.Ordinaria es una funcón que no contiene derivadas y que satisface a la EC.Dif. obteniendose una identidad.0
#
# ## Métodos de soluciones de EC.Dif. Ordinarias de primer orden:
#
# 1.   Método de variables separables
# 2.   Método por homogenias.
# 3.   Método por exactas.
# 4.   Método por factor integrante.
# 5.   Método por lineales.
# 6.   Método por no lineales (Bernoulli).
# 7.   Método por trayectorias ortogonales.
#
# Aplicación para resolver circuitos electronicos resistivos capacitivos (RC) y resistivos inductivos (RL).

# %% [markdown]
# ##Método para resolver EC.Dif. Por variables separables.
#
# >Se dice que una ecuación diferenciall de primer orden de la formula $\frac {dy}{dx} = g(x) h(y)$ es separable o por variables separables
#
#
# ##Ejemplo:
#
#
# ###1)   **$(1+x)dy-y dx=0$**
#
# &nbsp;
#
# Procedimiento:
#
# $(1+x) \frac {dy}{dx} -y=0$
#
# $(1+x)\frac{dy}{dx} = y$
#
# $\frac{dy}{dx}=y*\frac{1}{1+x}$
#
# $\int \frac{1}{4} \, dy=\int \frac{1}{1+x} \, dy$
#
# $e(ln|y|+c = ln|1+x|+c)$
#
# $e^{ln|y|} = e^{ ln|1+x|+c}$
#
# $|y|=|x+1|*c$
#
# $y= \overset{+}{-}c|x+1|$
#
#
# $y= \overset{+}{-}c(x+1)$
#
# $y= cx+c$
#
# $\frac{dy}{dx}=y'=c+0$
#
# $\frac{dy}{dx}=c$
#
# $c(1+x)-c(x+1)=0$

# %% [markdown]
# ##Ejercicios
#
#
#
# ###1)   $ y' = x e^{y-x^2}$
#
# &nbsp;
#
# $ \frac{dy}{dx} = e^{y-x^2} \cdot x $
#
# $ \frac{1}{e^{y-x^2}} \cdot \frac{dy}{dx} = x $
#
# $ \frac{1}{x} \cdot \frac{d}{dx}(y-x^2) = x $
#
# $ \frac{1}{x} \cdot (1 - 2x) = x $
#
# $ 1 - 2x = x^2 $
#
# $ x^2 + 2x - 1 = 0 $
#
# $ x = \frac{-2 \pm \sqrt{2^2 - 4 \cdot 1 \cdot (-1)}}{2 \cdot 1} = -1 \pm \sqrt{2} $
#
# $\text{Para } x = -1 + \sqrt{2}:$
#
# $ \int e^{y - (-1 + \sqrt{2})^2} \, dy = \int (-1 + \sqrt{2}) \, dx $
#
# $ \int (-1 + 2 - \sqrt{2}) \, dx = (-1 + 2 - \sqrt{2})x + C_2 $
#
# $ e^{y + 2\sqrt{2} - 1} + C_1 = (-1 + 2 - \sqrt{2})x + C_2 $
#
# &nbsp;
#
# ###2)  $y sen x  e^{cos x}dx + y^{-1} dy = 0$
#
# &nbsp;
#
# $y \sin(x) e^{\cos(x)}dx = -y^{-1} dy$
#
# $\int y \sin(x) d(e^{\cos(x)}) = \int -dy$
#
# $\int y \sin(x) d(e^u) = -\int dy$
#
# $\int y d(e^u) = -y + C_1$
#
# $y e^u + C_1 = -y + C_2$
#
# $y e^{\cos(x)} + C_1 = -y + C_2$
#
# $y(e^{\cos(x)} + 1) = C_2 - C_1$
#
# $y = \frac{C}{e^{\cos(x)} + 1}$

# %% [markdown]
# ## Método por factor integrante
# >Condición: Se aplica ecuaciones diferenciales ordinarias de primer orden lineales
#
# >Pasos:
#
# ###1.-Escribir la ecuación diferencial en su forma estándar
#
# &nbsp;
#
# $ \frac{dy}{dx}+ P(x) y= f(x) $
#
# &nbsp;
#
# ###2.- Hallar el factor integrante
#
# &nbsp;
#
# $  \upsilon (x)+=\varepsilon \int ^{p(x)dx} $
#
# &nbsp;
#
# ###3.-Evaluar la integral
#
# &nbsp;
#
# $ \int f(x) \cdot \upsilon (x) dx $
#
# &nbsp;
#
# ###4.-Escrbir la solución general
#
# &nbsp;
#
# $ y = \frac{\int f(x) u (x) dx + c }{u(x)} $
#
# &nbsp;
#
# ##Ejemplo
#
# ###Paso 1
#
# $y'+tan(x)y=cos^2(x)$
#
# $\frac{dy}{dx} + tan(x) y =cos ^{2} t(x) $
#
# $ P (x)= tan (x)$
#
# $ F(x)= cos ^{2} (x) $
#
# &nbsp;
#
# ###Paso 2
#
# $ \upsilon (x) = e^{\int tan (x) dx}=e^{ln(sec(x))} \therefore sec(x)$
#
# $\int tan(x) dx = lncos (x) = ln sec(x)$
#
# $cos ^{-1}(x)=\frac{1}{cos(x)}= sec(x)$
#
# &nbsp;
#
# ###Paso 3
#
# $ \int cos^{2}(x)\cdot sec (x)\cdot dx $
#
# $ \int cos(x)\cdot cos(x)\cdot \frac{1}{cos(x)} dx$
#
# $\int cos (x)dx= sen(x)+c $
#
# &nbsp;
#
# ###Paso 4
#
# $y\frac{sen(x)+c}{sec(x)}=\frac{sen(x)+c}{\frac{1}{cos(x)}} $
#
# $ y= cos(x)\cdot[sen (0)+c] $
#
# $2= cos(0)\cdot[sen(0) + c] $
#
# $2= 1\cdot[0 + c] $
#
# $c=2$
#
# $y=cos(x)\cdot[sen(x)+2]$

# %% [markdown]
# # Trasformada de La place
#
# >En cálculo elemental aprendió que la derivación y la integración son transformadas; esto significa, a grandes rasgos, que estas operaciones transforman una función en otra.
#
# >Por ejemplo, la función $f(x) = x^2$ se transforma, a su vez, en una función lineal y en una familia de
# funciones polinomiales cúbicas con las operaciones de derivación e integración:
#
# >$\frac {d}{dx}x^2 = 2x$ &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;y&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $\int x^2 dx=\frac{1}{3}x^3+c$
#
# &nbsp;
#
# ##Formula
#
# $f(s) = \mathcal{L} \{{f(t)} \} = \lim_{b \to \infty}  \int_{0}^{b} f{(t)} e^{-s t} \; dt$
#
# &nbsp;
#
# ##Ejemplos
#
#
# ###1) $f(t)=1$
#
# &nbsp;
#
# $\mathcal{L}  \{{f(1)} \} = \lim_{b \to \infty}  \int_{0}^{b} 1 · e^{-s t} \; dt$
#
# $\lim_{b \to \infty}[1·∫_{0}^{b}e^{-st}dt]$
#
# $\lim_{b \to \infty}[\frac{e^{-st}}{s}] \Biggr|_{0}^{b}$
#
# $\lim_{b \to \infty}[\frac{1}{s}(e^{-s (\infty)}-e^{-s (0)})]$
#
# $-\frac{1}{s}$
#
# $\mathcal{L} \{ 1 \} =  -\frac{1}{s}$
#
# &nbsp;
#
# ###2) $f(t)=t$
#
# $ \mathcal{L} \{ t \}=\lim_{b \to \infty} \int_{0}^{b}t\cdot e^{-st}dt=\frac{e^{-st}}{s}·t-\int_{0}^{b}\frac{e^{-st}}{s}dt $
#
# $-\frac{te^{-st}}{s}-\int-\frac{e^{st}}{s}dt=-\frac{te^{-st}}{s}+\frac{1}{s} \int^{-st}dt=\frac{1}{s} (\frac{e^{-st}}{s})$
#
# $\mathcal{L}\{s\}=-\frac{e^{st}}{s}-\frac{e^{st}}{s^2}|_{0}^{b}=\frac{1}{s^2}$
#
# $ \mathcal{L} \{ t \}=\frac{1}{s^2}$

# %% [markdown]
# ##Ejercicios
#
# ###1) $\mathcal{L} \{ t^2 e^{\alpha t} \}$
#
# $\mathcal{L} \ [ e^{\alpha} f(t) \ ] = \mathcal{L} \ [ f(t)\ ]_{s->s-\alpha}$
#
# $\mathcal{L} \{ t^n  e^{kt}\} = \frac{n!}{(s-k)^{n+1}}$
#
# $\mathcal{L} \{ t^2 \}_{s->s-4}$
#
# $[t^2] = \frac{2!}{s^2+1}$
#
# $\frac{s}{s^2} = \frac{2}{(s-4)^3}$
#
# $\mathcal{L} \{ t^2 e^{\alpha t} \} = \frac{2}{(s-4)^3}$
#
# &nbsp;
#
# ###2) $\mathcal{L} \{ t^3 \}$
#
# $\mathcal{L} \{ t^3 \} = \int_0^\infty t^3 e^{-st} \, dt$
#
#
# $\mathcal{L} \{ t^n \} = \frac{n!}{s^{n+1}}$
#
#
# $\mathcal{L} \{ t^3 \} = \frac{3!}{s^{3+1}} = \frac{6}{s^4}$
#
# $\mathcal{L} \{ t^3 \} = \frac{6}{s^4}$
#
# &nbsp;
#
# ###3) $\mathcal{L} \{ t e^{\alpha t} \}$
#
# $-\frac{d}{ds} \mathcal{L} \{ 3^{\alpha t} \} = -\frac{d}{ds} \frac{1}{s-3} = (s-3)^{-1} = \frac{1}{(s-3)^2} $
#
# $\mathcal{L} \{ t e^{\alpha t} \} = -\frac{d}{ds}\mathcal{L} \{  e^{\alpha t} \} = -\frac{d}{ds} \frac{1}{s-\alpha} = (s-\alpha)^{-2}$
#
# $\frac{1}{(s-\alpha)^2}$
#
# $\mathcal{L} \{ t e^{\alpha t} \} = \frac{1}{(s-\alpha)^2}$
#
# &nbsp;
#
# ###4) $\mathcal{L} \{ sen \beta t \}$
#
# $\int_0^\infty sen(\beta t) e^{-st} \, dt$
#
# $sen(\beta t) = \frac{1}{2i} \left( e^{i\beta t} - e^{-i\beta t} \right)$
#
# $\mathcal{L} \{ sen(\beta t) \} = \frac{1}{2i} \int_0^\infty e^{i\beta t} e^{-st} \, dt - \frac{1}{2i} \int_0^\infty e^{-i\beta t} e^{-st} \, dt$
#
# $\mathcal{L} \{ sen(\beta t) \} = \frac{1}{2i} \left( \frac{1}{s - i\beta} - \frac{1}{s + i\beta} \right)$
#
# $\mathcal{L} \{ sen(\beta t) \} = \frac{\beta}{s^2 + \beta^2}$
#
# &nbsp;
#
# ###5) $\mathcal{L} \{ e^{-3t} \}$
#
# $lim_{b->0} \int_{0}^{b} e^{-3t} e^{-st} dt$
#
# $lim_{b->0} \int_{0}^{b} e^{-(3+s)t}dt$
#
# $-\frac{e^{-(3+s)t}}{3+s}|_{0}^{b}$
#
# $[-\frac{1}{3+s}(e^{-(3+s)(b)}-e^{-(3+s)(0)}]$
#
# $\frac{1}{3+s}$
#
# $\mathcal{L} \{ e^{-3t} \} =\frac{1}{3+s}$
#
# &nbsp;
#
# ###6) $\mathcal{L} \{ sen 2t \}$
#
# $\lim_{b->0} \int_{0}^{b} e^{-st} sen 2t dt$
#
# $\lim_{b->0} -\frac{e^{-st}}{s} sen 2t |_{0}^{b} - \int_{0}^{b} -\frac{-e^{-st}}{s} 2 cos 2t dt$
#
# $\lim_{b->0} -\frac{e^{-st}}{s} sen 2t |_{0}^{b} + \frac{2}{5} \int_{0}^{b} e^{-st} cos 2t dt$
#
# $\lim_{b->0} \frac{1}{s}e^{-st} sen 2t |_{0}^{b} - \frac{2}{s^2} e^{-st} cos 2t |_{0}^{b} -\frac{4}{s^{2}} \int_{0}^{b} e^{-st} sen 2t dt$
#
# $\int_{0}^{b} sen 2t e^{-st} dt + \frac{4}{s^2} \int_{0}^{b} e^{-st} sen 2t dt$
#
# $\frac{1}{s} e^{-st} sen 2t|_{0}^{b}-\frac{2}{s^2}\cdotp e^{-st} c os 2t$
#
# $(1+4) \int_{0}^{b} sen 2t e^{-st} dt$
#
# $\frac{1}{s} e^{-st} sen 2t |_{0}^{b}-\frac{2}{s^2} e^{-st} cos 2t|_{0}^{b} -\frac{4}{s^2} \int_{0}^{b} e^{-st} sen 2t dt$
#
# $\int_{0}^{b} e^{-st} sen 2t dt + \frac{4}{s^2} \int_{0}^{b} e^{-st} sen 2t dt$
#
# $\frac{1}{s} e^{-st} sen 2t |_{0}{b} -\frac{2}{s^2} e^{-st} cos 2t |_{0}^{b}$
#
# $(1+\frac{4}{s^2}) \int_{0}^{b} e^{-st} sen 2t$
#
# $\frac{2}{s^2}$
#
# $\mathcal{L} \{ sen 2t \}=\frac{2}{s^2}$
#
# &nbsp;
#
# ###7) $\mathcal{L} \{ t cos t\}$
#
# $-\frac{d}{ds} \mathcal{L}\{cost\}$
#
# $-\frac{d}{ds} \frac{s}{s^2+1}$
#
# $-(\frac{(s^2+1)(1)-s(2s)}{(s^2+1)^2}$
#
# $-\frac{s^2+1-2s^2}{(s^2+1)^2}$
#
# $-\frac{1-s^2}{(s^2+1)^2}$
#
# $\frac{s^2-1}{(s^2+1)^2}$
#
# $\mathcal{L} \{ t cos t\}=\frac{s^2-1}{(s^2+1)^2}$
#
# &nbsp;
#
# ###8) $\mathcal{L} \{ e^{-t} sen t \}$
#
# $\int_{0}^{\infty} e^{-st} e^{-t} sen t = \int_{0}^{\infty} e^{-st-t} sen t = \int_{0}^{\infty} sen t e^{-(s+1)t}dt $
#
# $-\frac{1}{s+1} sen t e^{-(s+1)t} + \frac{1}{s+1} \int_{0}^{\infty}cos t e^{-s+1}dt$
#
# $\frac{1}{s+1} sen t e^{-(s+1)t} + \frac{1}{s+1} [-\frac{1}{s+1} cos t e^{(s+1)t}-\frac{1}{s+1}\int_{0}^{\infty}sen e^{-(s+1)t}dt]$
#
# $\int_{0}^{\infty} sen t e^{-(s+1)t} + \frac{1}{(s+1)^2}\int_{0}^{\infty} sen t e^{-()s+1}tdt = -\frac{1}{s+1} sen t e^{-(s+1)}-\frac{1}{(s+1)^2} cos t e^{-(s+1)t}$
#
# $[1\frac{1}{(s+1)^2}] \int_{0}^{\infty}sen t e^{-(s+1)}dt =\frac{1}{s+1}(sen(\infty)(e^{\infty}))-\frac{1}{(s+1)^2}(cos(\infty)(e^{\infty}))+ \frac{1}{s+1}(sin(0)(e^0))+\frac{1}{(s+1)^2} cos(0)(e^0)$
#
# $\frac{(s+1)^2+1}{(s+1)^2}\int_{0}^{\infty}sen t e^{-(s+1)t}dt = \frac{1}{(s+1)^2+1}$
#
# $\frac{(s+1)^2+1}{(s+1)^2}\int_{0}^{\infty}sen t e^{-(s+1)t}dt = \frac{1}{s^2+2s+2}$
#
# $\mathcal{L} \{ e^{-t} sen t \} = \frac{1}{s^2+2s+2}$
#
# &nbsp;
#
# ###9) $\mathcal{L} \{ cos^2 t \}$
#
# $\mathcal{L} \{ \frac{1+cos 2t}{2} \} -> \frac{1}{2} \mathcal{L} \{ 1+ cos 2t \} -> \frac{1}{2} { \mathcal{L} \{1\} +\mathcal{L} \{ cos 2 t \}}$
#
# $\mathcal{L} \{ cos 2t \} = \lim_{b->\infty} \int_{0}^{b} cos 2t e^{-st} dt = \frac{e^{-st}}{s} cos 2t|_{0}^{b}-\frac{2}{s}\int_{0}^{b} e^{-st} sen 2t dt $
#
# $\frac{-e^{-st}}{s} cos 2t |_{0}^{b} -\frac{2}{s}[-\frac{e^{-st}}{s}sen 2t +\frac{2}{s}\int_{0}^{b}e^{-st} cos 2t dt]$
#
# $\lim_{b->\infty} -\frac{1}{s} e^{-st} cos 2t |_{0}^{b} + \frac{2}{s^2} e^{-st} sen 2t |_{0}^{b}-\frac{4}{s^2}\int_{0}^{b} e^{-st} cos t 2t dt-> \int_{0}^{b} e^{-st} cos2t dt= -\frac{1}{s} e^{-st} cos 2t |_{0}^{b}+\frac{2}{s^2}e^{-st} sen 2t|_{0}^{b}$
#
# $(1+\frac{4}{s^2}) \int_{0}^{b} e^{-st} cos 2t dt = -\frac{1}{s} e^{-st} cos t 2t |_{0}^{b} + \frac{2}{s^2} sen 2t |_{0}^{b}$
#
# $[(-\frac{1}{s} -s(b) cos 2(b))+ \frac{2}{s^2} e^{-st(b)}sen 2(b)]-[-\frac{1}{s} e^{-s(0)} cos 2(0) + \frac{2}{s^2} e^{s(0)} sen 2(0)]$
#
# $\frac{1}{s}\int_{0}^{b}e^{-st}cos 2t dt = \frac{\frac{1}{s}}{\frac{6^2+4}{s^2}}=\frac{s}{s^2+4}= \mathcal{L} \{ cos 2t \} = \frac{s}{s^2+4}$
#
# $\frac{1}{2}[\frac{1}{s} + \frac{s}{s^2+4}] = \frac{1}{2s} +\frac{s}{2s^2+8} = \frac{s^2+2}{s(s^2+4)}$
#
# $\mathcal{L} \{ cos^2 t \} =\frac{s^2+2}{s(s^2+4)}$
# &nbsp;
#
# ###10) $\mathcal{L} \{ e^t senh t \}$
#
# $e^t(\frac{e^{t}-e^{-t}}{2})= \frac{e^{2t}-e^{0}}{2}= \frac{e^{2t}-1}{2}=\frac{e^{2t}}{2} - \frac{1}{2}$
#
# $\mathcal{L} \{\frac{e^{2t}}{2}-\frac{1}{2}\}$
#
# $\frac{1}{2} \mathcal{L} \{ e^{2t}\} - \frac{1}{2} \mathcal{L} \{ 1\}$
#
# $\mathcal{L} \{ e^{at} \} = \frac{1}{s-2}$
#
# $\mathcal{L} \{1 \} = \frac{1}{s}$
#
# $\frac{1}{2} \cdotp \frac{1}{s-2} - \frac{1}{2} \cdotp \frac{1}{s}$
#
# $\frac{1}{2(s-2)}$
#
# $\mathcal{L} \{ e^t senh t \}=\frac{1}{2(s-2)}$
#
# &nbsp;
#
# ###11) $\mathcal{L} \{ \frac{1+cos 2t}{2}\}$
#
# $\int_{0}^{\infty}(\frac{1+cos 2t}{2} )e^{-st} dt $
#
# $\int_{0}^{\infty} \frac{e^{-st}}{2} dt + \int_{0}^{\infty} cos 2t e^{st} dt$
#
# $\int_{0}^{\infty} \frac{e^{st}}{2} dt = \frac{1}{2} \int_{0}^{\infty} e^{-st} dt $
#
# $\frac{1}{2} \int_{0}^{\infty} \frac{e^u du}{-s} = -\frac{1}{2} \int_{0}^{\infty} e^u du$
#
# $\frac{1}{2s} e^u \frac{du}{-s} = -\frac{1}{2} \int_{0}^{\infty} e^u du $
#
# $-\frac{1}{2s} e^u |_{0}^{\infty}- \frac{1}{2s} e^{-st} |_{0}^{\infty}$
#
# $\int_{0}^{\infty} cos 2t e^{-st} dt = cos 2t (\frac{-e^{-st}}{s}) -\int_{0}^{\infty} (\frac{-e^{-st}}{s}) - (- 2 sen 2t) dt$
#
# $\frac{-cos 2t (e^{-st})}{2} + \frac{2}{s} \int_{0}^{\infty} e^{-st} (-sen 2t) dt$
#
# $\frac{-cos 2t (e^{-st})}{2}+ \frac{2}{s} [sen 2t(\frac{-e^{-st}}{s})-\int_{0}^{\infty}(\frac{-e^{-st}}{s})(-2 cos 2t)dt]$
#
# $\int_{0}^{\infty}(\frac{1+cos 2t}{2}) e^{-2t} dt = -\frac{1}{2s}e^{-st}+(\frac{\frac{-cos 2t e^{-st}}{s}-\frac{2 sen st e^{-st}}{s^2}}{(\frac{4}{s^22}+1)}$
#
# $\frac{1}{2^s} + \frac{\frac{1}{3}}{\frac{4}{s^2}+1} = \frac{1}{2s} + \frac{\frac{1}{s}}{\frac{4+s^2}{s^2}}$
#
# $\frac{1}{2s} + \frac{s^2}{s(4+s^2)} = \frac{1}{2}(\frac{1}{s}+\frac{s}{s^2+4}) = \frac{1}{2} (\frac{1}{s} + \frac{s}{s^2 + 4})$

# %% [markdown]
# ##Trasformada de Laplace
#
# $$ \mathcal{L} \{ \alpha f(t)+ \beta g(t)\}= \alpha  \mathcal{L} \{ f(t)\} + \beta  \mathcal{L} \{ g(t) \}$$
#
# ##Identidad
#
# $\mathcal{L} \{ 1\}= \frac{1}{s}$
#
# $\mathcal{L} \{ e^\alpha t \}= \frac{1}{s-\alpha}$
#
# $\mathcal{L} \{ cos k t \}= \frac{s}{s^2+k^2}$
#
# $\mathcal{L} \{ t^n\}= \frac{n!}{s^{n+1}}$
#
# $\mathcal{L} \{ 1sen k t \}= \frac{k}{k^2+S^2}$
#
# $\mathcal{L} \{ senhkt\}= \frac{k}{s^2-k^2}$
#
# $\mathcal{L} \{ cos h k t \}= \frac{s}{s^2-k^2}$

# %% [markdown]
# ##Identidad de funciones trigonometricas hiperbolicas
#
# $\frac{d sen hx}{dx} = \frac{e^x-e^{-x}}{2} = cos hx$
#
# $\frac{d cos hx}{dx} = \frac{e^x-e^{-x}}{2} = sen hx$
#
# $\int cos hx dx=senhx+c$
#
# $\int sen hx = cos hx +c$

# %% [markdown]
# ##Trasformada inversa
#
# >Si $F(s)$ representa la transformada de Laplace de una
# función $f(t)$, es decir, $\mathcal {L} \ {f(t) \ } = F(s)$ , se dice entonces que $f (t)$ es la **transformada
# de Laplace inversa** de $F(s)$ y se escribe $f(t) =  \mathcal{L^{-1}} \{F(s) \}$
#
# &nbsp;
#
# ##Identidades
#
# $$F(t)=\mathcal{L}^{-1}\{f(s)\}=\mathcal{L}^{-1}\{\mathcal{L}\{f(t)\}\}$$
#
# $k=\mathcal{L}^{-1}\left\{\frac{k}{5}\right\}$
#
# $t^n=\mathcal{L}^{-1}\left\{\frac{1}{s^{n+1}}\right\} $
#
# $e^{-3 t}=\mathcal{L}^{-1}\left\{\frac{1}{s+3}\right\}$
#
# ${sen} k t=\mathcal{L}^{-1}\left\{\frac{k}{s^2+k^2}\right\}$
#
# ${cos} k t=\mathcal{L}^{-1}\left\{\frac{s}{s^2+k^2}\right\}$

# %% [markdown]
# ##Ejercicios
#
# ###1) $\mathcal{L^{-1}}  \{\frac{1}{s^3+5s} \}$
#
# $\mathcal{L}^{-1} \left\{ \frac{1}{s^3+5s} \right\} = \mathcal{L}^{-1} \left\{ \frac{1}{s(s^2+5)} \right\}$
#
#
#
# $\frac{1}{s(s^2+5)} = \frac{A}{s} + \frac{Bs+C}{s^2+5}$
#
# $1 = A(s^2+5) + (Bs+C)s$
#
# $1 = As^2 + 5A + B s^2 + Cs$
#
# $A + B = 0$
#
# $5A + C = 0$
#
# $\frac{1}{s(s^2+5)} = \frac{0}{s} + \frac{0s+0}{s^2+5}$
#
# $\mathcal{L}^{-1} \left\{ \frac{0}{s} + \frac{0s+0}{s^2+5} \right\} = \frac{0}{1} + 0 \cos(\sqrt{5}t) + 0 \sin(\sqrt{5}t)$
#
# $\mathcal{L}^{-1} \left\{ \frac{1}{s^3+5s} \right\} = 0$
#
# &nbsp;
#
# ###2) $\mathcal{L^{-1}}  \{\frac{s+1}{s^2-4s} \} $
#
# $\frac{s+1}{s^2-4 s}=\frac{A}{s}+\frac{B}{s-4}$
#
# $\frac{A}{s} \cdot \frac{(s-4)}{(s-4)}+\frac{B}{s-4} \cdot \frac{s}{s}=\frac{A(s-4)+B s}{s(s-4)}$
#
# $\frac{(s+1)}{s(s+4)} \therefore A(s-4)+B \cdot s=s+1$
#
# $\mathcal{L}^{-1}\left\{-\frac{1}{4} \frac{1}{s}+\frac{s}{4} \frac{1}{s-4}\right\}=-\frac{1}{4}+\frac{s}{4} e^{-4} $
#
# &nbsp;
#
# ###3) $\mathcal{L^{-1}}  \{\frac{2s+5}{(s-3)^{2}} \}$
#
# $\frac{2 s+5}{(s-3)^2}=\frac{A}{(s-3)}+\frac{B}{(s-3)^2}$
#
# $\frac{2 s+5}{(s-3)^2}=\frac{2}{(s-3)}+\frac{11}{(s-3)^2}$
#
# $\frac{2 s+5}{(s+3)^2}\frac{2}{s-3}+\frac{11}{s-3^2}$
#
# $\mathcal{L^{-1}} \left\{\frac{2s+5}{(s-3)^2}\right\}= \mathcal{L}^{-1} \left\{\frac{2}{(s-3)}\right\} + \mathcal{L^{-1}}\left\{\frac{11}{(s-3)^2}\right\}$
#
# $2 \mathcal{L}^{-1} \left\{\frac{1}{(s-3)}\right\} +11 \mathcal{L^{-1}}\left\{\frac{11}{(s-3)^2}\right\}$
#
# $(11t+2)e^{3t}$
#
# &nbsp;
#
# ###4) $\mathcal{L^{-1}}  \{\frac{2s-3}{s^2-7s-8} \}$
#
# $\mathcal{L}^{-1} \left\{ \frac{2s-3}{s^2-7s-8} \right\} = \mathcal{L}^{-1} \left\{ \frac{2s-3}{(s-8)(s+1)} \right\}$
#
#
# $\frac{2s-3}{(s-8)(s+1)} = \frac{A}{s-8} + \frac{B}{s+1}$
#
# $2s-3 = A(s+1) + B(s-8)$
#
# $2s-3 = As + A + Bs - 8B$
#
# $A + B = 2$
#
# $-8B + A = -3$
#
# $\frac{2s-3}{(s-8)(s+1)} = \frac{-1}{s-8} + \frac{3}{s+1}$
#
# $\mathcal{L}^{-1} \left\{ \frac{-1}{s-8} + \frac{3}{s+1} \right\} = -e^{8t} + 3e^{-t}$
#
# $\mathcal{L}^{-1} \left\{ \frac{2s-3}{s^2-7s-8} \right\} = -e^{8t} + 3e^{-t}$
#
# &nbsp;
#
# ###5) $\mathcal{L^{-1}}  \{\frac{4s}{4s^2+1} \}$
#
# $\mathcal{L}^{-1} \left\{ \frac{4s}{4s^2+1} \right\}$
#
# $\frac{4s}{4s^2+1} = \frac{4s}{(2s)^2+1^2}$
#
# $\mathcal{L}^{-1} \left\{ \frac{4s}{4s^2+1} \right\} = \sin(t)$
#
# &nbsp;
#
# ###6) $\mathcal{L^{-1}}  \{\frac{s}{(s^2+4)(S+2)} \} $
#
# $\mathcal{L}^{-1} \left\{ \frac{s}{(s^2+4)(s+2)} \right\}$
#
#
# $\frac{s}{(s^2+4)(s+2)} = \frac{A}{s+2} + \frac{Bs+C}{s^2+4}$
#
# $s = A(s^2+4) + (Bs+C)(s+2)$
#
# $s = As^2 + 4A + Bs^2 + 2Bs + Cs + 2C$
#
# $A + B = 0$
#
# $2B + C = 0$
#
# $4A + 2C = 1$
#
# $( A = \frac{1}{4} ), \\( B = -\frac{1}{4} ) \\( C = \frac{1}{2} ).$
#
#
# $\frac{s}{(s^2+4)(s+2)} = \frac{1}{4(s+2)} - \frac{1}{4(s^2+4)} + \frac{1}{2(s^2+4)}$
#
# $\mathcal{L}^{-1} \left\{ \frac{1}{4(s+2)} - \frac{1}{4(s^2+4)} + \frac{1}{2(s^2+4)} \right\} = \frac{1}{4}e^{-2t} - \frac{1}{4}\sin(2t) + \frac{1}{2}\cos(2t)$
#
# $\mathcal{L}^{-1} \left\{ \frac{s}{(s^2+4)(s+2)} \right\} = \frac{1}{4}e^{-2t} - \frac{1}{4}\sin(2t) + \frac{1}{2}\cos(2t)$
#
# &nbsp;
#
# ###7) $\mathcal{L^{-1}}  \{\frac{s-1}{s^2(S^2+1)} \} $
#
# $\mathcal{L}^{-1} \left\{ \frac{s-1}{s^2(s^2+1)} \right\}$
#
# $\frac{s-1}{s^2(s^2+1)} = \frac{A}{s} + \frac{B}{s^2} + \frac{Cs+D}{s^2+1}$
#
# $s-1 = A(s^2+1) + B(s^2+1) + (Cs+D)s^2$
#
# $s-1 = (A+B)s^2 + (A+D)s + B$
#
# $A + B = 0$
#
# $A + D = 1$
#
# $B = -1$
#
# $(A = -\frac{1}{2}) \\(B = -1)  \\(D = \frac{3}{2})$
#
# $\frac{s-1}{s^2(s^2+1)} = -\frac{1}{2s} - \frac{1}{s^2} + \frac{\frac{3}{2}s+1}{s^2+1}$
#
# $\mathcal{L}^{-1} \left\{ -\frac{1}{2s} - \frac{1}{s^2} + \frac{\frac{3}{2}s+1}{s^2+1} \right\} = -\frac{1}{2} - t + \frac{3}{2}\cos(t) + \sin(t)$
#
# $\mathcal{L}^{-1} \left\{ \frac{s-1}{s^2(s^2+1)} \right\} = -\frac{1}{2} - t + \frac{3}{2}\cos(t) + \sin(t)$
#
# &nbsp;
#
# ###8) $\mathcal{L^{-1}}  \{\frac{(s+1)^3}{S^4} \}$
#
# $\mathcal{L}^{-1} \left\{ \frac{(s+1)^3}{s^4} \right\}$
#
# $\frac{(s+1)^3}{s^4} = \left( \frac{s+1}{s} \right)^3$
#
# $\mathcal{L}^{-1} \left\{ \frac{(s+1)^3}{s^4} \right\} = e^{-t} \mathcal{L}^{-1} \left\{ \left( \frac{s+1}{s} \right)^3 \right\}$
#
# $\mathcal{L}^{-1} \left\{ \left( \frac{s+1}{s} \right)^3 \right\} = e^{-t} \left( t^3 + 3t^2 + 3t + 1 \right)$
#
# $\mathcal{L}^{-1} \left\{ \frac{(s+1)^3}{s^4} \right\} = e^{-t} \left( t^3 + 3t^2 + 3t + 1 \right)$

# %% [markdown]
# ##Trasformada de Laplace de derivada
#
# >El objetivo inmediato es usar la transformada de Laplace para resolver ecuaciones
# diferenciales. Para tal fin, es necesario evaluar cantidades como $\mathcal{L^{-1}}  \{{dy}/{dt} \}$ y $\mathcal{L^{-1}}  \{{d^2y}/{d^{2}} \}$
#
# ###Ejemplo
#
# ### 1) $\mathcal{L}  \{f'(t) \}= \lim_{b \to \ 0} \int_{0}^{b}f'(t) \cdotp e^{-st} dt = \lim_{b \to \ 0} [e^{-st}f(t)|_{0}^{b} + s \int_{0}^{b}e^{-st}f(t)dt]$
#
# $\lim_{b \to \infty}[e^{-st}f(b)-e^0 f(0)] + \lim_{b \to \infty} sF(s) = s F(s)-f(0)$
#
# $\mathcal{L}  \{f'(t) \} = s F(s)-f(0)$

# %% [markdown]
# # Series de fourier
#
# >El motivo fundamental de desarrollar estas herramientas para llevar acabo el análisis en el dominio de la frecuencia es proporcionar una representación matemática y gráfica de las componentes de frecuencia contenidas en una determinada señal.
#
# ##Formula:
#
# $\frac{a_0}{s}+\sum _{n=1}^{\infty}[a_n cos(\frac{nπx}{L})+b_n sen (\frac{nπx}{L})]$
#
# $a_o=\frac{1}{L}\int_{-L}^{L}f(x)dx$
#
# $a_n=\frac {1}{L} \int_{-L}^{L}f(x) cos(\frac{nπx}{L})dx$
#
# $b_n=\frac{1}{L}\int_{-L}^{L}f(x)sen (\frac{nπx}{L})$
#
#
# ##Ejemplo
#
# $a_0=\frac{1}{n}\int_{-\pi}^{\pi}xdx=\frac{1}{\pi}[\frac{x^2}{2}]   \Biggr|_{-\pi}^{\pi} =\frac{1}{2\pi}[\left|{\substack{\text{} (\pi)^2-(-\pi)^2 \\ \text{} \pi^2-\pi^2}}\right.]=a_0=0$
#
# $b_n=\frac{1}{n}\int_{-\pi}^{\pi}x sen(nx)dx=\frac{1}{n} [ \frac{-xcos (nx)}{n}|_{-\pi}^{\pi} + \frac{1}{n} \int_{-\pi}{\pi} cos (nx) dx]$
#
# $\frac{1}{n}[-\frac{1}{n}(\pi cos(n\pi)-(-\pi)cos (-n\pi))+ \frac{1}{n^2}sen (nx) |_{-\pi}^{\pi}]$
#
# $\frac{1}{n}[-\frac{1}{n}(\pi(-1)^n+\pi(-1)^n)]$
#
# $\frac{\pi^n}{\pi}[-\frac{1}{n}(\pi(-1)^n+\pi(-1)^n]$
#
# $-\frac{(-1)^n}{n}-\frac{(-1)^n}{n}=-\frac{2(-1)^n}{n}-\frac{2(-1)(-1)^n}{n}$
#
# $b_n= \frac{2(-1)^{n+1}}{n}$

# %% [markdown]
# ## Ejercicios
# $F(x)= e^{-4x} para 12\leq  x \leq  2$
#
# Determina su serie de fourier
#
# $do=\frac{I}{L}f(x)dx$
#
# $cn=\frac{I}{L} \int_{T}^{-T}F(t)e^{^{-2i\Pi \frac{t}{T}}}dt  $
#
# $do=\frac{1}{4}\int_{-2}^{2}e^{-4x}dx$
#
# $u=14x$                  $du=14xdx$
#
# $-\frac{1}{4}\int edx= -\frac{1}{4} e ^{14x}|=-\frac{1}{4}\sqsubset e^{-4(2)} - e^{14(-2)}\sqsupset =-\frac{1}{4}\sqsubset e^{15} - e^{8}\sqsupset = -\frac{1}{4}\left ( \frac{e^{16}-1}{e} \right )=\frac{e^{16}-1}{4e^{8}}$
#
#
# $\frac{1}{e^{8}}-\frac{e^{8}}{1}=\frac{1-e^{16}}{e^{8}} \frac{1}{2}\left ( \frac{e^{16}-1}{4e^{8}} \right )=\frac{e^{16}-1}{8e^{8}}$
#
# $cn=\frac{1}{2}\int_{2}^{-2}e^{-4t}\cdot e\frac{sin\prod t }{2}dt=\frac{1}{2}\int_{2}^{-2}e^{-4t}\cdot e^{in\prod t}dt=\frac{1}{2}\int_{2}^{-2}e^{(4+in\prod )\cdot t}dt$
#
# $u=(4+in\prod )-t$.  $du=-4in\prod $
#
# $\sqsubset \frac{1}{-4-in\prod }  (e^{2=in\prod }-e^{6+in\prod })\sqsupset \cdot \left ( \frac{1}{2} \right )=\frac{e^{2+in\prod }-e^{6+in\prod }}{(-4-in\prod ^{2})}=\frac{e^{2+in\prod }-e^{6+in\prod }}{-8-2in\prod }= Cn $
#
# RESULTADO
#
# $cn+\sum_{n=+-\infty }^{\infty} Cn  e^{^{2in\prod t}}$
#
#
# 2.-Determinar la serie de fourier de onda cuadrada
# $ f(x)0 si -\prod \leq x\leq$
#
# $f(x)1 si 0 \leq x< \prod   $
#
# $ao=\frac{1}{t}\int_{T}^{-T} f(x)dx $
#
# $ao=\frac{1}{t}\int_{T}^{-T} f(x)dx $
#
#
# $\cdot an=\frac{2}{t}\int_{-t}^{t}f(x)\cdot cos(nx)dx.$
#
# $an=\frac{2}{2\prod }\int_{\prod }^{0} o cos(nx)dx+\int_{0}^{\prod }1\cdot cos(nx)dx$
#
#  $u=nx$.  $du=n$
